# %% [markdown]
# ### WEB SCRAPING – ASSIGNMENT 4

# %%
# Importing Libraries

import selenium

import pandas as pd

from selenium import webdriver

from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException

from selenium.webdriver.common.by import By

import time


from bs4 import BeautifulSoup
import requests

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Scrape the details of most viewed videos on YouTube from Wikipedia.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening Wikipedia webpage
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)
time.sleep(2)

# %%
driver.maximize_window()

# %%
# Empty list for scraping data
Rank =[]
Name =[]
Artist =[]
Upload_date=[]
Views=[]

# %%
# Extracting Rank Via X path
try:
    rank=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
except StaleElementReferenceException:
    Rank.append('NA')
    
# Extracting Name Via X path
try:
    name=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in name:
        Name.append(i.text)
except NoSuchElementExceptionhElementException:
    Name.append('NA')
except StaleElementReferenceException:
    Name.append('NA')
    
# Extracting Artist Name Via Xpath
try:
    artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artist:
        Artist.append(i.text)
except NoSuchElementExceptionhElementException:
    Artist.append('NA')
except StaleElementReferenceException:
    Artist.append('NA')

# Extracting Upload date Via Xpath
try:
    upload_date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date:
        Upload_date.append(i.text)
except NoSuchElementExceptionhElementException:
    Upload_date.append('NA')
except StaleElementReferenceException:
    Upload_date.append('NA') 

# Extracting Views via Xpath
try:
    views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views:
        Views.append(i.text)
except NoSuchElementExceptionhElementException:
    Views.append('NA')
except StaleElementReferenceException:
    Views.append('NA')

# %%
len(Rank),len(Name),len(Artist),len(Upload_date),len(Views)
# Out:
# (30, 30, 30, 30, 30)

# %%
# Dataframe for scrap data
Wiki_YT=pd.DataFrame({'Rank':Rank,'Video Name':Name,'Uploader':Artist,'Upload Date':Upload_date,'Views (in Billons)':Views})
print('\033[1m'+'Most Viewed Video on YouTube from Wikipedia :'+'\033[0m')
Wiki_YT
# Out:
# Most Viewed Video on YouTube from Wikipedia :
#    Rank                                       Video Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                     "Axel F"[34]
# 14  15.                                      "Sugar"[35]
# ...

# %%
driver.close()

# %% [markdown]
# ### 2. Scrape the details teamIndia’sinternationalfixtures from bcci.tv.

# %%
# Importing Libraries

import selenium

import pandas as pd

from selenium import webdriver

from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException

from selenium.webdriver.common.by import By

import time


from bs4 import BeautifulSoup
import requests

import warnings
warnings.filterwarnings('ignore')

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening Wikipedia webpage
url='https://www.bcci.tv/'
driver.get(url)
time.sleep(1)

# %%
driver.maximize_window()

# %%
#Clicking international fixture section
international=driver.find_element(By.XPATH,'//a[@class="nav-link "]')
driver.get(international.get_attribute('href'))

# %%
# Creating empty list
Match_title = []
Series = []
Place = []
Date = []
Time = []

# %%
 
# Scraping Match title
try:
    title=driver.find_element(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
    Match_title.append(title.text)
except NoSuchElementException:
    Match_title.append('NA')
        
# Scraping Series Via Xpath
try:
    series=driver.find_element(By.XPATH,'//div[@class="match-card-middle__inner d-flex justify-content-between"]')
    Series.append(series.text)
except NoSuchElementException:
    Series.append('NA')
        
 # Scraping venue Via Xpath
try:
    place=driver.find_element(By.XPATH,'//span[@class="ng-binding"]')
    Place.append(place.text)
except NoSuchElementException:
    Place.append('NA')
        
# Scraping date Via Xpath
try:
    date=driver.find_element(By.XPATH,'//div[@class="match-dates ng-binding"]')
    Date.append(date.text)
except NoSuchElementException:
    Date.append('NA')
        
# Scraping Time Via Xpath
try:
    time=driver.find_element(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
    Time.append(time.text)
except NoSuchElementException:
    Time.append('NA')

# %%
len(Match_title),len(Series),len(Place),len(Date),len(Time)
# Out:
# (1, 1, 1, 1, 1)

# %%
# Dataframe for scrap data
Cricket=pd.DataFrame({'Match Title':Match_title,'Tournament':Series,'Venue':Place,'Date':Date,'Time':Time})
print('\033[1m'+'Team India’s Upcoming International fixtures :'+'\033[0m')
Cricket
# Out:
# Team India’s Upcoming International fixtures :
#                               Match Title            Tournament   Venue  \
# 0  ICC WORLD TEST CHAMPIONSHIP FINAL 2023  India\nvs\nAustralia  London
#
#          Date         Time
# 0  7 JUN 2023  3:30 PM IST

# %%
#Closing the driver
driver.close()

# %% [markdown]
# ### 3. Scrape the details of State-wise GDP ofIndia fromstatisticstime.com.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening Wikipedia webpage
url='https://www.statisticstimes.com/'
driver.get(url)
time.sleep(1)

# %%
driver.maximize_window()

# %%
# Clicking on Ecomony section
economy = driver.find_element(By.XPATH,'//*[@id="top"]/div[2]/div[2]/button')
economy.click()

# %%
# Clicking on India under ecomony section
ind = driver.find_element(By.XPATH,'//*[@id="top"]/div[2]/div[2]/div/a[3]')  
ind.click()

# %%
# Clicking Indian State GDP
gdp = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a') 
gdp.click()

# %%
# Creating Empty lists

Rank =[]
State =[]
GDSP_18_19 =[]
GDSP_19_20 =[]
Share =[]
GDP =[]

# %%
# Extracting Rank via Xpath
try:
    rank=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
    
# Extracting state name via Xpath
try:
    state=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[2]')
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('NA')
    
# Extracting GDSP 19-20 via Xpath
try:
    gdsp_19_20=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[3]')
    for i in gdsp_19_20:
        GDSP_19_20.append(i.text)
except NoSuchElementException:
    GDSP_19_20.append('NA')
    
# Extracting GDSP 18-19 via Xpath
try:
    gdsp_18_19=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[4]')
    for i in gdsp_18_19:
        GDSP_18_19.append(i.text)
except NoSuchElementException:
    GDSP_18_19.append('NA')
    
# Extracting share in billons via Xpath
try:
    share=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[5]')
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('NA')

# Extracting GDP via Xpath
try:
    gdp=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[6]')
    for i in gdp:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('NA')

# %%
len(Rank),len(State),len(GDSP_18_19),len(GDSP_19_20),len(Share),len(GDP)
# Out:
# (33, 33, 33, 33, 33, 33)

# %%
# Dataframe for scrap data

Statewise_GDP=pd.DataFrame({'Rank':Rank,'State':State,'GDSP 18-19':GDSP_18_19,'GDSP 19-20':GDSP_19_20,'Share':Share,'GDP (in Billions)':GDP})
print('\033[1m'+'State-wise GDP of India :'+'\033[0m')
Statewise_GDP
# Out:
# State-wise GDP of India :
#    Rank                      State GDSP 18-19 GDSP 19-20   Share  \
# 0     1                Maharashtra  2,632,792          -  13.94%
# 1     2                 Tamil Nadu  1,630,208  1,845,853   8.63%
# 2     3              Uttar Pradesh  1,584,764  1,687,818   8.39%
# 3     4                    Gujarat  1,502,899          -   7.96%
# 4     5                  Karnataka  1,493,127  1,631,977   7.91%
# 5     6                West Bengal  1,089,898  1,253,832   5.77%
# 6     7                  Rajasthan    942,586  1,020,989   4.99%
# 7     8             Andhra Pradesh    862,957    972,782   4.57%
# 8     9                  Telangana    861,031    969,604   4.56%
# 9    10             Madhya Pradesh    809,592    906,672   4.29%
# 10   11                     Kerala    781,653          -   4.14%
# 11   12                      Delhi    774,870    856,112   4.10%
# 12   13                    Haryana    734,163    831,610   3.89%
# ...

# %%
driver.close()

# %% [markdown]
# ### 4. Scrape the details of trending repositories on Github.com.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening github webpage
url='https://github.com/'
driver.get(url)
time.sleep(1)

# %%
driver.maximize_window()

# %%
explore = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
explore.click()

# %%
trending = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
trending.click()

# %%
# Creating Empty list for Scraping Data

Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]

# %%
#scraping the Repositor_Name 
R_t=driver.find_elements(By.XPATH,'//span[@class="text-normal"]')
for i in R_t:
    if i.text is None :
        Repository_title.append("--") 
    else:
        Repository_title.append(i.text)

# %%
#scraping the Description 
des=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in des:
    if i.text is None :
        Repository_description.append("--")
    else:
        Repository_description.append(i.text)

# %%
#scraping the Language 
lan=driver.find_elements(By.XPATH,'//span[@itemprop="programmingLanguage"]')
for i in lan:
    if i.text is None :
        Language_used.append("--") 
    else:
        Language_used.append(i.text)

# %%
#scraping the Contributors_count
con=driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"]')
for i in con:
    if i.text is None :
        Contributors_count.append("--") 
    else:
        Contributors_count.append(i.text)

# %%
# Dataframe for scrap data

Github=pd.DataFrame({'Repository_title':Repository_title[:25],'Repository_description':Repository_description[:25],'Contributors_count':Contributors_count[:25],'Language_used':Language_used[:25]})
print('\033[1m'+'GitHub Trending Repository :'+'\033[0m')
Github
# Out:
# GitHub Trending Repository :
#     Repository_title                             Repository_description  \
# 0          suno-ai /             🔊 Text-Prompted Generative Audio Model
# 1        OpenLMLab /  An open-source tool-augmented conversational l...
# 2           xtekky /  decentralising the Ai Industry, free gpt-4/3.5...
# 3   sanchit-gandhi /                                         ⚖️ AI 法律助手
# 4          lvwzhen /  ChatGPT interface with better UI + running on ...
# 5           xtekky /  mall项目是一套电商系统，包括前台商城系统及后台管理系统，基于SpringBoot+MyB...
# 6       macrozheng /                                Python - 100天从新手到大师
# 7        jackfrued /  Auto-GPT中文版本及爱好者组织 同步更新原项目 AI领域创业 自媒体组织 用AI工作学...
# 8        kaqijiang /                              潘多拉，一个不只是命令行的ChatGPT。
# 9        pengzhile /  Inpaint anything using Segment Anything and in...
# 10       geekyutao /                Superpower ChatGPT Chrome Extension
# 11     saeedezzati /  😎 Awesome lists about all kinds of interesting...
# ...

# %%
driver.close()

# %% [markdown]
# ### 5. Scrape the details of top 100 songs on billiboard.com.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening billboard webpage
url='https://www.billboard.com/'
driver.get(url)
time.sleep(1)

# %%
driver.maximize_window()

# %%
nav=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[1]/div[1]/button')
nav.click()

time.sleep(2)

# %%
#Hot 100 songs

hot_100=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a')
hot_100.click()

# %%
# Creating Empty List

Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
#Scrapping the data having the song name
song_nam=driver.find_elements(By.XPATH,'//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]')
for i in song_nam:
    if i.text is None:
        Song_name.append('-')
    else:
        Song_name.append(i.text)

# %%
#Scrapping the data having the Artist_name

artist_nam=driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
for i in artist_nam:
    if i.text is None:
        Artist_name.append('-')
    else:
        Artist_name.append(i.text)

# %%
#Scrapping the data having the Last_week_rank

last_rank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]')
for i in last_rank:
    if i.text is None:
        Last_week_rank.append('-')
    else:
        Last_week_rank.append(i.text)

# %%
#Scrapping the data having the Peak_rank

peak_rank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max"]')
for i in peak_rank:
    if i.text is None:
        Peak_rank.append('-')
    else:
        Peak_rank.append(i.text)

# %%
#Scrapping the data having the Weeks_on_board

board=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]')
for i in board:
    if i.text is None:
        Weeks_on_board.append('-')
    else:
        Weeks_on_board.append(i.text)

# %%
# Dataframe for scrap data

billiboard=pd.DataFrame({'Song_name':Song_name[:99],'Artist_name':Artist_name[:99],'Last_week_rank':Last_week_rank[:99],'Peak_rank':Peak_rank[:99],'Weeks_on_board':Weeks_on_board[:99]})
billiboard
# Out:
#             Song_name                              Artist_name Last_week_rank  \
# 0          Last Night                            Morgan Wallen              4
# 1             Flowers                              Miley Cyrus             19
# 2      Princess Diana                  Ice Spice & Nicki Minaj              1
# 3     Ella Baila Sola              Eslabon Armado X Peso Pluma             12
# 4            Creepin'     Metro Boomin, The Weeknd & 21 Savage              3
# ..                ...                                      ...            ...
# 94        Memory Lane                             Old Dominion              -
# 95         Love Again                            The Kid LAROI              1
# 96         '98 Braves                            Morgan Wallen             36
# 97          Di Que Si  Grupo Marca Registrada X Grupo Frontera             23
# 98  It Matters To Her                          Scotty McCreery             60
#
#    Peak_rank Weeks_on_board
# ...

# %%
driver.close()

# %% [markdown]
# ### 6. Scrape the details of Highest sellingnovels.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening Highest sellingnovels webpage
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)
time.sleep(1)

# %%
driver.maximize_window()

# %%
# Creating Empty Lists
Book =[]
Author =[]
Volumes_sold =[]
Publisher =[]
Genre =[]

# %%
# Scraping Book name
try:
    book=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
    for i in book:
        Book.append(i.text)
except NoSuchElementException:
    Book.append('NA')

# %%
# Scraping Book author's via Xpath
try:
    author=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
    for i in author:
        Author.append(i.text)
except NoSuchElementException:
    Author.append('NA')

# %%
# Scraping Volumes sold via Xpath
try:
    sold=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
    for i in sold:
        Volumes_sold.append(i.text)
except NoSuchElementException:
    Volumes_sold.append('NA')

# %%
# Scraping publisher via xPath
try:
    publisher=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
    for i in publisher:
        Publisher.append(i.text)
except NoSuchElementException:
    Publisher.append('NA')

# %%
# Scraping Genre via Xpath
try:
    genre=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('NA')

# %%
#creating dataframe
Top_Books=pd.DataFrame({"Book Title":Book,
                "Author Name":Author,
                'Volumes sold':Volumes_sold,
                'Publisher':Publisher,
                'Genre':Genre})
print('\033[1m'+'Best Selling Books of All Time List by The Guardian  :'+'\033[0m')
Top_Books
# Out:
# Best Selling Books of All Time List by The Guardian  :
#                                            Book Title       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
# ...

# %%
driver.close()

# %% [markdown]
# ### 7. Scrape the details most watched tv series of all time from imdb.com.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening imdb webpage
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)
time.sleep(1)

# %%
driver.maximize_window()

# %%
# Creating Empty List
Name =[]
Year_Span=[]
Genre =[]
Run_Time =[]
Ratings =[]
Votes =[]

# %%
# Scraping Name via Xpath
try:
    name=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('NA')

# %%
# Scraping Year span via Xpath
try:
    year=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/span[2]')
    for i in year:
        Year_Span.append(i.text)
except NoSuchElementException:
    Year_Span.append('NA')

# %%
# Scraping Genre via Xpath
try:
    genre=driver.find_elements(By.XPATH,'//span[@class="genre"]')
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('NA')

# %%
# Scraping RunTime via Xpath
try:
    runtime=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
    for i in runtime:
        Run_Time.append(i.text)
except NoSuchElementException:
    Run_Time.append('NA')

# %%
# Scraping Ratings via Xpath
try:
    ratings=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]/span[2]')
    for i in ratings:
        Ratings.append(i.text)
except NoSuchElementException:
    Ratings.append('NA')

# %%
# Scraping Votes via Xpath
try:
    votes=driver.find_elements(By.XPATH,'//span[@name="nv"]')
    for i in votes:
        Votes.append(i.text)
except NoSuchElementException:
    Votes.append('NA')

# %%
#creating dataframe
IMDB_TV=pd.DataFrame({"Name":Name,"Year Span":Year_Span,"Genre":Genre,"Run Time":Run_Time,"Ratings":Ratings,"Votes":Votes})
print('\033[1m'+'Top 100 most watched tv shows of all time IMDB :'+'\033[0m')
IMDB_TV
# Out:
# Top 100 most watched tv shows of all time IMDB :
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
# ...

# %%
driver.close()

# %% [markdown]
# ### 8. Details of Datasets from UCI machine learning repositories.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening uci webpage
url='https://archive.ics.uci.edu/'
driver.get(url)
time.sleep(1)

# %%
driver.maximize_window()

# %%
#Clicking on view all datasets link
datasets=driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b')
try:
    datasets.click()
except ElementNotInteractableException:
    driver.get(datasets.get_attribute('href'))

# %%
#Creating empty lists for storing the scrapped data
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_Instance=[]
No_of_Attribute=[]
Year=[]

# %%
#Scrapping the data having dataset name
try:
    names=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a')
    for i in names:
        Dataset_name.append(i.text)
except NoSuchElementException:
    Dataset_name.append('-')

# %%
#Scrapping the data having data type
try:
    types=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]')
    for i in types[1:]:
        Data_type.append(i.text)
except NoSuchElementException:
    Data_type.append('-')

# %%
#Scrapping the data having default task
try:
    task=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]')
    for i in task[1:]:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('-')

# %%
#Scrapping the data having attribute types
try:
    attribute=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]')
    for i in attribute[1:]:
        Attribute_type.append(i.text)
except NoSuchElementException:
    Attribute_type.append('-')

# %%
#Scrapping the data having no of instances
try:
    instance=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]')
    for i in instance[1:]:
        No_of_Instance.append(i.text)
except NoSuchElementException:
    No_of_Instance.append('-')

# %%
#Scrapping the data having no of attributes
try:
    attribute_no=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]')
    for i in attribute_no[1:]:
        No_of_Attribute.append(i.text)
except NoSuchElementException:
    No_of_Attribute.append('-')

# %%
#Scrapping the data having the year details
try:
    year=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]')
    for i in year[1:]:
        Year.append(i.text)
except NoSuchElementException:
    Year.append('-')

# %%
len(Dataset_name),len(Data_type),len(Task),len(Attribute_type),len(No_of_Instance),len(No_of_Attribute),len(Year)
# Out:
# (622, 622, 622, 622, 622, 622, 622)

# %%
# Creating Data Frame for UCI Dataset
UCI_Dataset=pd.DataFrame({'Dataset_name':Dataset_name,'Data Type':Data_type,'Task':Task,'Attribute Type':Attribute_type,'No of Instances':No_of_Instance,'No of Attribute':No_of_Attribute,'Year':Year})
print('\033[1m'+' UCI Machine Learning Dataset:'+'\033[0m')
UCI_Dataset
# Out:
#  UCI Machine Learning Dataset:
#                                           Dataset_name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data Type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# ...

# %%
driver.close()

# %% [markdown]
# ### 9. Scrape the details of Data science recruiters Url = https://www.naukri.com/hr-recruiters-consultants

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Rabi Kumar\Downloads\File\chormedriver.exe")
time.sleep(1)

# %%
# Opening naukri webpage
url='https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)
time.sleep(1)

# %%
driver.maximize_window()

# %%
#Searching the input key and sending the key as Data Science.
    
search = driver.find_element(By.XPATH,'//input[@class="sugInp"]')
search.send_keys("Data science")

# %%
#Searching the search Button and Clicking it.
   
search_btn = driver.find_element(By.XPATH,'//button[@class="fl qsbSrch blueBtn"]')
search_btn.click()

# %%
# Creating Empty List
Name =[]
Designation =[]
Company =[]
Skill =[]
Location =[]

# %%
# Scraping  Name
try:
    name=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
        Name.append('NA')

# Scraping Designation
try:
    designation=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
    for i in designation:
        Designation.append(i.text)
except NoSuchElementException:
    Designation.append('NA')
    
# Scraping Company
try:
    company=driver.find_elements(By.XPATH,'//a[@class="ellipsis"][2]')
    for i in company:
        Company.append(i.text)
except NoSuchElementException:
    Company.append('NA')
# Scraping skill for they hire
try:
    skill=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
    for i in skill:
        Skill.append(i.text)
except NoSuchElementException:
    Skill.append('NA')
    
# Scraping Song Artist Name
try:
    location=driver.find_elements(By.XPATH,'//small[@class="ellipsis"]')
    if location:
        for i in location:
            Location.append(i.text)
    else:
        Location.append('NA')
except NoSuchElementException:
    Location.append('NA')

# %%
len(Name),len(Designation),len(Company),len(Skill),len(Location)
# Out:
# (50, 50, 50, 50, 49)

# %%
recruiters=pd.DataFrame({'Name':Name[:49],'Designation':Designation[:49],'Company':Company[49],'Skill':Skill[49],'Location':Location})
print('\033[1m'+'Naukri.com Data Science recruiters :'+'\033[0m')
recruiters
# Out:
# Naukri.com Data Science recruiters :
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                 Priyanka Akiri
# 14                                   Kapil Devang
# 15                             Mahesh Babu Channa
# 16                             Vaishnavi Kudalkar
# ...

# %%
driver.close()
